# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../../../data/raw/dataset-bids/south-bangkok power plant, samut prakan-air-quality.csv', parse_dates=['date'])

# %%
# trim white space of column names
df.columns = df.columns.str.strip()

# %%
def fill_numeric(col):
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
fill_numeric('pm25')
fill_numeric('pm10')
fill_numeric('o3')
fill_numeric('no2')
fill_numeric('so2')
fill_numeric('co')

# %%
# heatmap of missing value for pm25
plt.figure(figsize=(12, 8))
sns.heatmap(df.isna(), cbar=False)
plt.show()

# %%
# correlation matrix
sns.heatmap(df.drop(columns=['date']).corr(), annot=True)
# Out:
# <Axes: >
