# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../../../data/raw/dataset-bids/highway-district, samut sakhon-air-quality.csv', parse_dates=['date'])

# %%
df.head()
# Out:
#         date  pm25  pm10  o3  no2  so2  co
# 0 2024-10-01    48
# 1 2024-10-02    38
# 2 2024-10-03    37
# 3 2024-10-04    46
# 4 2024-10-05    77

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3241 entries, 0 to 3240
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3241 non-null   datetime64[ns]
#  1    pm25   3241 non-null   object
#  2    pm10   3241 non-null   object
#  3    o3     3241 non-null   object
#  4    no2    3241 non-null   object
#  5    so2    3241 non-null   object
#  6    co     3241 non-null   object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 177.4+ KB

# %%
# trim white space of column names
df.columns = df.columns.str.strip()

# %%
def fill_numeric(col):
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
fill_numeric('pm25')
fill_numeric('pm10')
fill_numeric('o3')
fill_numeric('no2')
fill_numeric('so2')
fill_numeric('co')

# %%
# heatmap of missing value for pm25
plt.figure(figsize=(12, 8))
sns.heatmap(df.isna(), cbar=False)
plt.show()

# %%
df.isna().sum()
# Out:
# date       0
# pm25    1200
# pm10    1062
# o3      1053
# no2     1047
# so2     1095
# co      2601
# dtype: int64

# %%
sns.pairplot(df)

# %%
# correlation matrix
sns.heatmap(df.drop(columns=['date']).corr(), annot=True)
# Out:
# <Axes: >
